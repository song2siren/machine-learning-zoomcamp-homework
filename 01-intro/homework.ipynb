# %% [markdown]
# # Homework 1

# %% [markdown]
# ## Q1. Pandas version
#
# What version of Pandas did you install?

# %%
import pandas as pd

pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# ## Getting the data

# %%
import os
import pandas as pd

filename = "car_fuel_efficiency_2026.csv"
url = "https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv"

if not os.path.exists(filename):
    # !wget {url} -O {filename}

df = pd.read_csv(filename)
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %% [markdown]
# ## Q2. Records count
#
# How many records are in the dataset?
#
# - 5000
# - 9000
# - 10000
# - 15000

# %%
len(df)
# Out:
# 10000

# %% [markdown]
# ## Q3. Fuel types
#
# How many fuel types are presented in the dataset?
#
# - 1
# - 2
# - 3
# - 4

# %%
df['fuel_type'].unique()
# Out:
# <StringArray>
# ['Gasoline', 'Diesel', 'Hybrid']
# Length: 3, dtype: str

# %% [markdown]
# ## Q4. Missing values
# How many columns in the dataset have missing values?
#
# - 0
# - 1
# - 2
# - 3
# - 4

# %%
missing_count = int((df.isnull().sum() > 0).sum())
cols_with_missing = df.columns[df.isnull().any()]

print(f"Columns with missing values ({missing_count}): {list(cols_with_missing)}")
# Out:
# Columns with missing values (2): ['horsepower', 'acceleration']

# %% [markdown]
# ## Q5. Max fuel efficiency
# What's the maximum fuel efficiency of cars from Asia?
#
# - 21.2
# - 31.2
# - 41.2
# - 51.2

# %%
float(df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max())
# Out:
# 41.2

# %% [markdown]
# ## Q6. Median value of horsepower
# Find the median value of the horsepower column in the dataset.
# Next, calculate the most frequent value of the same horsepower column.
# Use the ```fillna``` method to fill the missing values in the horsepower column with the most frequent value from the previous step.
# Now, calculate the median value of horsepower once again.
# Has it changed?
#
# - Yes, it increased
# - Yes, it decreased
# - No

# %%
median_before = df['horsepower'].median()
mode_value = df['horsepower'].mode()[0]

horsepower_filled = df['horsepower'].fillna(mode_value)

median_after = horsepower_filled.median()

print(f"Median value of the horsepower column: {median_before}")
print(f"Most frequent value of the same horsepower column: {mode_value}")
print(f"Median value of the horsepower column after filling: {median_after}")

if median_after > median_before:
    answer = "Yes, it increased"
elif median_after < median_before:
    answer = "Yes, it decreased"
else:
    answer = "No"

print(answer)
# Out:
# Median value of the horsepower column: 254.0
# Most frequent value of the same horsepower column: 252.0
# Median value of the horsepower column after filling: 252.0
# Yes, it decreased

# %% [markdown]
# ## Q7. Sum of weights
# 1. Select all the cars from Asia
# 2. Select only columns ```vehicle_weight``` and ```model_year```
# 3. Select the first 7 values
# 4. Get the underlying NumPy array. Let's call it ```X```.
# 5. Compute matrix-matrix multiplication between the transpose of ```X``` and ```X```. To get the transpose, use ```X.T.``` Let's call the result ```XTX```.
# 6. Invert ```XTX```.
# 7. Create an array ```y``` with values ```[1100, 1300, 800, 900, 1000, 1100, 1200]```.
# 8. Multiply the inverse of ```XTX``` with the transpose of ```X```, and then multiply the result by ```y```. Call the result ```w```.
# 9. What's the sum of all the elements of the result?
#
# Note: You just implemented linear regression. We'll talk about it in the next lesson.
#
# - 0.0369
# - 0.369
# - 3.69
# - 36.9

# %%
import numpy as np

asia_df = df[df['origin'] == 'Asia']
X = asia_df[['vehicle_weight', 'model_year']].head(7).values

XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)

y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

w = XTX_inv.dot(X.T).dot(y)

print(w)
print(w.sum())
# Out:
# [0.13644777 0.2327492 ]
# 0.36919696904925486
